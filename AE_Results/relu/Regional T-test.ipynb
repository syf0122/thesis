# %%
import pandas as pd
import numpy as np
import statsmodels as sm
from scipy import stats as st
from bioinfokit.analys import stat
import matplotlib.pyplot as plt
import hcp_utils as hcp
from nilearn import plotting as nlp
from nilearn.plotting.cm import _cmap_d as cm
from tabulate import tabulate
# Out:
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1

# %%
subjects = [100610, 102311, 102816, 104416, 105923,
            108323, 109123, 111514, 114823, 115017,
            115825, 116726, 118225, 125525, 126426,
            128935, 130114, 130518, 131217, 131722,
            132118, 134627, 134829, 135124, 137128,
            140117, 144226, 145834, 146129, 146432,
            146735, 146937, 148133, 150423, 155938,
            156334, 157336, 158035, 158136, 159239,
            162935, 164131, 164636, 165436, 167036,
            167440, 169040, 169343, 169444, 169747]
mse_sub = []
for sub in subjects:
    loc = 'ae_MSE/' + str(sub) + '_regional_MSE_2.csv'
    df = pd.read_csv(loc,index_col=0)
    mse_sub.append(df)    
print('There are ' + str(len(mse_sub)) + ' subjects.')
print('For each subject, there are ' + str(mse_sub[0].shape[0]) + ' sessions.')
print('For each session, there are ' + str(mse_sub[0].shape[1]) + ' regional MSE.')
# Out:
# There are 50 subjects.
# For each subject, there are 14 sessions.
# For each session, there are 379 regional MSE.

# %%
m1 = pd.DataFrame()
for sub in mse_sub:
    m1 = pd.concat([m1, sub.iloc[[0]]], ignore_index = True, axis = 0)
print(m1.shape)
m1.head()
# Out:
# (50, 379)
#        L_V1     L_MST      L_V6      L_V2      L_V3      L_V4      L_V8  \
# 0  0.331925  0.303235  0.504088  0.134815  0.108276  0.176851  0.624035
# 1  0.363432  0.612150  0.395281  0.136720  0.190083  0.163781  0.374189
# 2  0.442110  0.358441  0.476539  0.070030  0.123449  0.113188  0.279980
# 3  0.338304  0.357051  0.572221  0.136440  0.203937  0.196298  0.521626
# 4  0.292410  0.553853  0.567011  0.124312  0.131993  0.204234  0.238631
#
#         L_4      L_3b     L_FEF  ...  diencephalon_right  hippocampus_left  \
# 0  0.165220  0.377096  1.092119  ...            0.128131          0.115918
# 1  0.192794  0.278712  0.634410  ...            0.155744          0.110858
# 2  0.125977  0.252148  0.541359  ...            0.170075          0.140691
# 3  0.110735  0.244549  0.371600  ...            0.157242          0.230129
# 4  0.117698  0.274145  0.337691  ...            0.196945          0.131477
#
#    hippocampus_right  pallidum_left  pallidum_right  putamen_left  \
# ...

# %%
m2 = pd.DataFrame()
for sub in mse_sub:
    m2 = pd.concat([m2, sub.iloc[[1]]], ignore_index = True, axis = 0)
print(m2.shape)
m2.head()
# Out:
# (50, 379)
#        L_V1     L_MST      L_V6      L_V2      L_V3      L_V4      L_V8  \
# 0  0.239030  0.434067  0.364328  0.120894  0.147240  0.253314  0.573581
# 1  0.277661  0.618207  0.484352  0.107159  0.139658  0.199691  0.321480
# 2  0.464146  0.498544  0.533652  0.084318  0.081304  0.128838  0.369152
# 3  0.348643  0.581353  0.571996  0.116483  0.152445  0.203745  0.636555
# 4  0.283584  0.548574  0.460419  0.103428  0.097633  0.184306  0.230053
#
#         L_4      L_3b     L_FEF  ...  diencephalon_right  hippocampus_left  \
# 0  0.167927  0.239516  1.010726  ...            0.115770          0.142471
# 1  0.185010  0.324919  0.518788  ...            0.138760          0.134764
# 2  0.203998  0.147291  1.200654  ...            0.131106          0.114140
# 3  0.129172  0.349789  0.458676  ...            0.210114          0.206545
# 4  0.154445  0.207969  0.358252  ...            0.175658          0.118201
#
#    hippocampus_right  pallidum_left  pallidum_right  putamen_left  \
# ...

# %%
m3 = pd.DataFrame()
for sub in mse_sub:
    m3 = pd.concat([m3, sub.iloc[[2]]], ignore_index = True, axis = 0)
print(m3.shape)
m3.head()
# Out:
# (50, 379)
#        L_V1     L_MST      L_V6      L_V2      L_V3      L_V4      L_V8  \
# 0  0.246763  0.541083  0.618400  0.091157  0.107164  0.172301  0.573326
# 1  0.364142  0.729585  0.363077  0.100340  0.157565  0.198285  0.417496
# 2  0.397356  0.421462  0.466618  0.111966  0.145800  0.137309  0.377499
# 3  0.259937  0.597674  0.815918  0.091277  0.126120  0.114830  0.343251
# 4  0.330351  0.537091  0.740364  0.123929  0.140927  0.198339  0.196847
#
#         L_4      L_3b     L_FEF  ...  diencephalon_right  hippocampus_left  \
# 0  0.173120  0.356595  0.489977  ...            0.156889          0.113319
# 1  0.156034  0.229446  0.584001  ...            0.118431          0.163902
# 2  0.199996  0.241678  0.469403  ...            0.142900          0.249521
# 3  0.129876  0.231789  0.447234  ...            0.158941          0.221693
# 4  0.105598  0.228238  0.396675  ...            0.196945          0.192882
#
#    hippocampus_right  pallidum_left  pallidum_right  putamen_left  \
# ...

# %%
m4 = pd.DataFrame()
for sub in mse_sub:
    m4 = pd.concat([m4, sub.iloc[[3]]], ignore_index = True, axis = 0)
print(m4.shape)
m4.head()
# Out:
# (50, 379)
#        L_V1     L_MST      L_V6      L_V2      L_V3      L_V4      L_V8  \
# 0  0.242169  0.410084  0.367533  0.095629  0.199289  0.168793  0.848551
# 1  0.287315  0.733029  0.409075  0.085168  0.146588  0.159510  0.372704
# 2  0.491072  0.410131  0.721222  0.103245  0.107069  0.105461  0.336382
# 3  0.260541  0.446353  0.670872  0.124543  0.205380  0.197802  0.589797
# 4  0.303302  0.549747  0.506418  0.136274  0.160481  0.152434  0.229765
#
#         L_4      L_3b     L_FEF  ...  diencephalon_right  hippocampus_left  \
# 0  0.122534  0.313088  0.747733  ...            0.187380          0.107221
# 1  0.152830  0.240201  0.396749  ...            0.237123          0.150566
# 2  0.214376  0.251395  0.421470  ...            0.172096          0.138664
# 3  0.123082  0.244056  0.382654  ...            0.150381          0.161021
# 4  0.117588  0.189967  0.393304  ...            0.243857          0.171716
#
#    hippocampus_right  pallidum_left  pallidum_right  putamen_left  \
# ...

# %%
m_all = pd.DataFrame()
for sub in mse_sub:
    m_all = pd.concat([m_all, sub.iloc[[0]]], ignore_index = True, axis = 0)
    m_all = pd.concat([m_all, sub.iloc[[1]]], ignore_index = True, axis = 0)
    m_all = pd.concat([m_all, sub.iloc[[2]]], ignore_index = True, axis = 0)
    m_all = pd.concat([m_all, sub.iloc[[3]]], ignore_index = True, axis = 0)
print(m_all.shape)
m_all.head()
# Out:
# (200, 379)
#        L_V1     L_MST      L_V6      L_V2      L_V3      L_V4      L_V8  \
# 0  0.331925  0.303235  0.504088  0.134815  0.108276  0.176851  0.624035
# 1  0.239030  0.434067  0.364328  0.120894  0.147240  0.253314  0.573581
# 2  0.246763  0.541083  0.618400  0.091157  0.107164  0.172301  0.573326
# 3  0.242169  0.410084  0.367533  0.095629  0.199289  0.168793  0.848551
# 4  0.363432  0.612150  0.395281  0.136720  0.190083  0.163781  0.374189
#
#         L_4      L_3b     L_FEF  ...  diencephalon_right  hippocampus_left  \
# 0  0.165220  0.377096  1.092119  ...            0.128131          0.115918
# 1  0.167927  0.239516  1.010726  ...            0.115770          0.142471
# 2  0.173120  0.356595  0.489977  ...            0.156889          0.113319
# 3  0.122534  0.313088  0.747733  ...            0.187380          0.107221
# 4  0.192794  0.278712  0.634410  ...            0.155744          0.110858
#
#    hippocampus_right  pallidum_left  pallidum_right  putamen_left  \
# ...

# %%
r1 = pd.DataFrame()
for sub in mse_sub:
    r1 = pd.concat([r1, sub.iloc[[4]]], ignore_index = True, axis = 0)
print(r1.shape)
r1.head()
# Out:
# (50, 379)
#        L_V1     L_MST      L_V6      L_V2      L_V3      L_V4      L_V8  \
# 0  0.232448  0.453695  0.393931  0.139537  0.143834  0.130141  0.478462
# 1  0.213628  0.451817  0.379691  0.114712  0.211131  0.166470  0.413735
# 2  0.431144  0.493233  0.532703  0.111858  0.125203  0.175883  0.361083
# 3  0.253081  0.343259  0.418706  0.136254  0.223180  0.215823  0.611346
# 4  0.223049  0.512617  0.350463  0.120548  0.133039  0.144840  0.202546
#
#         L_4      L_3b     L_FEF  ...  diencephalon_right  hippocampus_left  \
# 0  0.141677  0.339898  0.815644  ...            0.129228          0.162041
# 1  0.237835  0.245961  0.493285  ...            0.118721          0.202565
# 2  0.173001  0.367089  1.943543  ...            0.165205          0.167874
# 3  0.127132  0.293254  0.345912  ...            0.164621          0.175168
# 4  0.114986  0.187543  0.356738  ...            0.234339          0.233444
#
#    hippocampus_right  pallidum_left  pallidum_right  putamen_left  \
# ...

# %%
r_all = pd.DataFrame()
for sub in mse_sub:
    r_all = pd.concat([r_all, sub.iloc[[4]]], ignore_index = True, axis = 0)
    r_all = pd.concat([r_all, sub.iloc[[5]]], ignore_index = True, axis = 0)
    r_all = pd.concat([r_all, sub.iloc[[6]]], ignore_index = True, axis = 0)
    r_all = pd.concat([r_all, sub.iloc[[7]]], ignore_index = True, axis = 0)
print(r_all.shape)
r_all.head()
# Out:
# (200, 379)
#        L_V1     L_MST      L_V6      L_V2      L_V3      L_V4      L_V8  \
# 0  0.232448  0.453695  0.393931  0.139537  0.143834  0.130141  0.478462
# 1  0.277942  0.461584  0.327560  0.113895  0.122642  0.152139  0.542107
# 2  0.213053  0.671421  0.252871  0.110605  0.175383  0.237731  0.700548
# 3  0.316324  0.524729  0.236711  0.141448  0.145151  0.230711  0.615231
# 4  0.213628  0.451817  0.379691  0.114712  0.211131  0.166470  0.413735
#
#         L_4      L_3b     L_FEF  ...  diencephalon_right  hippocampus_left  \
# 0  0.141677  0.339898  0.815644  ...            0.129228          0.162041
# 1  0.232130  0.377266  0.631004  ...            0.135149          0.109718
# 2  0.169860  0.367362  0.679404  ...            0.089160          0.138826
# 3  0.164954  0.358545  0.762241  ...            0.143768          0.115427
# 4  0.237835  0.245961  0.493285  ...            0.118721          0.202565
#
#    hippocampus_right  pallidum_left  pallidum_right  putamen_left  \
# ...

# %%
t1 = pd.DataFrame()
for sub in mse_sub:
    t1 = pd.concat([t1, sub.iloc[[8]]], ignore_index = True, axis = 0)
print(t1.shape)
t1.tail()
# Out:
# (50, 379)
#         L_V1     L_MST      L_V6      L_V2      L_V3      L_V4      L_V8  \
# 45  0.332389  0.304788  0.560040  0.198825  0.132855  0.294086  0.922416
# 46  0.217698  0.400577  0.347942  0.112498  0.134482  0.296371  0.611327
# 47  0.498507  0.708236  0.605150  0.258744  0.308147  0.238108  0.632080
# 48  0.412511  0.932679  0.605847  0.120589  0.206140  0.339620  1.451396
# 49  0.335489  0.480956  0.527498  0.096573  0.144213  0.283235  0.687393
#
#          L_4      L_3b     L_FEF  ...  diencephalon_right  hippocampus_left  \
# 45  0.170681  0.206229  0.537663  ...            0.126226          0.185837
# 46  0.102751  0.188315  0.290576  ...            0.087226          0.157213
# 47  0.089494  0.153557  0.420314  ...            0.121992          0.112247
# 48  0.429020  0.298255  0.436464  ...            0.289453          0.134164
# 49  0.103533  0.223783  0.313442  ...            0.138085          0.204869
#
# ...

# %%
t_all = pd.DataFrame()
for sub in mse_sub:
    t_all = pd.concat([t_all, sub.iloc[[8]]], ignore_index = True, axis = 0)
    t_all = pd.concat([t_all, sub.iloc[[9]]], ignore_index = True, axis = 0)
    t_all = pd.concat([t_all, sub.iloc[[10]]], ignore_index = True, axis = 0)
    t_all = pd.concat([t_all, sub.iloc[[11]]], ignore_index = True, axis = 0)
    t_all = pd.concat([t_all, sub.iloc[[12]]], ignore_index = True, axis = 0)
    t_all = pd.concat([t_all, sub.iloc[[13]]], ignore_index = True, axis = 0)
print(t_all.shape)
t_all.head()
# Out:
# (300, 379)
#        L_V1     L_MST      L_V6      L_V2      L_V3      L_V4      L_V8  \
# 0  0.373485  0.645782  0.527373  0.170864  0.301889  0.337355  0.743064
# 1  0.262636  0.586444  0.423806  0.141629  0.317076  0.304016  1.034242
# 2  0.458282  0.822051  0.957989  0.203010  0.679942  1.161122  1.774137
# 3  0.424959  0.463078  0.725673  0.086190  0.123686  0.096473  0.694477
# 4  0.388646  0.900425  0.506428  0.200243  0.689544  1.124014  1.770894
#
#         L_4      L_3b     L_FEF  ...  diencephalon_right  hippocampus_left  \
# 0  0.116046  0.350194  1.080298  ...            0.112757          0.145123
# 1  0.107676  0.264604  0.533833  ...            0.129964          0.150354
# 2  0.139274  0.337415  0.504023  ...            0.150454          0.181180
# 3  0.191766  0.232658  0.820142  ...            0.191549          0.140108
# 4  0.212855  0.451587  0.656929  ...            0.200706          0.165779
#
#    hippocampus_right  pallidum_left  pallidum_right  putamen_left  \
# ...

# %% [markdown]
# # Paired T-Test (One-tailed)

# %%
# movie1 vs rest1
t_mr, p_mr_r = st.ttest_rel(m1, r1, alternative='greater')
tf_mr, p_mr = sm.stats.multitest.fdrcorrection(p_mr_r)
count = 0
for n in tf_mr:
    if n:
        count += 1
print("There are " + str(count) + " regions that are significantly different between movie1 and rest1.")
# calculate z values
z_mr = st.norm.ppf(1-p_mr)

regions = m1.columns
for n in range(len(regions)):
    if z_mr[n] < 1.65:
        z_mr[n] = 0
nlp.view_surf(hcp.mesh.inflated,hcp.cortex_data(hcp.unparcellate(z_mr, hcp.mmp)), bg_map=hcp.mesh.sulc, cmap=cm['black_red'], threshold=1.65, symmetric_cmap = False, vmax = 6, vmin = 1.65).save_as_html('z_m1r1.html')

tb = [['Region Name', 'P-Value']]
for n in range(len(regions)):
    p = p_mr[n]
    if p <= 0.05:
        tb.append([regions[n],p])

print(len(tb)-1)
print(tabulate(tb, headers='firstrow', tablefmt='fancy_grid'))
# Out:
# There are 13 regions that are significantly different between movie1 and rest1.
# 13
# ╒═══════════════╤═════════════╕
# │ Region Name   │     P-Value │
# ╞═══════════════╪═════════════╡
# │ L_V6          │ 8.01435e-05 │
# ├───────────────┼─────────────┤
# │ L_V3A         │ 1.38476e-07 │
# ├───────────────┼─────────────┤
# │ L_FFC         │ 0.00216529  │
# ├───────────────┼─────────────┤
# │ L_1           │ 4.36027e-05 │
# ├───────────────┼─────────────┤
# │ L_VMV1        │ 0.00859741  │
# ├───────────────┼─────────────┤
# │ R_V6          │ 8.01435e-05 │
# ├───────────────┼─────────────┤
# │ R_V3A         │ 3.2885e-06  │
# ├───────────────┼─────────────┤
# │ R_V7          │ 0.00127174  │
# ├───────────────┼─────────────┤
# │ R_PSL         │ 0.0196028   │
# ├───────────────┼─────────────┤
# │ R_1           │ 0.00852135  │
# ├───────────────┼─────────────┤
# │ R_VMV1        │ 0.000223694 │
# ├───────────────┼─────────────┤
# │ R_PI          │ 0.00255284  │
# ...

# %%
# movie2 vs rest1
t_mr, p_mr_r = st.ttest_rel(m2, r1, alternative='greater')
tf_mr, p_mr = sm.stats.multitest.fdrcorrection(p_mr_r)
count = 0
for n in tf_mr:
    if n:
        count += 1
print("There are " + str(count) + " regions that are significantly different between movie2 and rest1.")
# calculate z values
z_mr = st.norm.ppf(1-p_mr)

regions = m2.columns
for n in range(len(regions)):
    if z_mr[n] < 1.65:
        z_mr[n] = 0
nlp.view_surf(hcp.mesh.inflated,hcp.cortex_data(hcp.unparcellate(z_mr, hcp.mmp)), bg_map=hcp.mesh.sulc, cmap=cm['black_red'], threshold=1.65, symmetric_cmap = False, vmax = 6, vmin = 1.65).save_as_html('z_m2r1.html')

tb = [['Region Name', 'P-Value']]
for n in range(len(regions)):
    p = p_mr[n]
    if p <= 0.05:
        tb.append([regions[n],p])

print(len(tb)-1)
print(tabulate(tb, headers='firstrow', tablefmt='fancy_grid'))
# Out:
# There are 17 regions that are significantly different between movie2 and rest1.
# 17
# ╒═══════════════╤═════════════╕
# │ Region Name   │     P-Value │
# ╞═══════════════╪═════════════╡
# │ L_V6          │ 0.00030939  │
# ├───────────────┼─────────────┤
# │ L_V3A         │ 1.56765e-06 │
# ├───────────────┼─────────────┤
# │ L_V7          │ 0.00238191  │
# ├───────────────┼─────────────┤
# │ L_1           │ 0.00210424  │
# ├───────────────┼─────────────┤
# │ L_OP4         │ 0.042875    │
# ├───────────────┼─────────────┤
# │ R_V6          │ 0.00210424  │
# ├───────────────┼─────────────┤
# │ R_V3A         │ 0.00029089  │
# ├───────────────┼─────────────┤
# │ R_V7          │ 5.10769e-05 │
# ├───────────────┼─────────────┤
# │ R_PSL         │ 1.18319e-05 │
# ├───────────────┼─────────────┤
# │ R_v23ab       │ 0.00931906  │
# ├───────────────┼─────────────┤
# │ R_31pv        │ 0.0442274   │
# ├───────────────┼─────────────┤
# │ R_7PC         │ 0.0222573   │
# ...

# %%
# movie3 vs rest1
t_mr, p_mr_r = st.ttest_rel(m3, r1, alternative='greater')
tf_mr, p_mr = sm.stats.multitest.fdrcorrection(p_mr_r)
count = 0
for n in tf_mr:
    if n:
        count += 1
print("There are " + str(count) + " regions that are significantly different between movie3 and rest1.")
# calculate z values
z_mr = st.norm.ppf(1-p_mr)

regions = m3.columns
for n in range(len(regions)):
    if z_mr[n] < 1.65:
        z_mr[n] = 0
nlp.view_surf(hcp.mesh.inflated,hcp.cortex_data(hcp.unparcellate(z_mr, hcp.mmp)), bg_map=hcp.mesh.sulc, cmap=cm['black_red'], threshold=1.65, symmetric_cmap = False, vmax = 6, vmin = 1.65).save_as_html('z_m3r1.html')

tb = [['Region Name', 'P-Value']]
for n in range(len(regions)):
    p = p_mr[n]
    if p <= 0.05:
        tb.append([regions[n],p])

print(len(tb)-1)
print(tabulate(tb, headers='firstrow', tablefmt='fancy_grid'))
# Out:
# There are 17 regions that are significantly different between movie3 and rest1.
# 17
# ╒═══════════════╤═════════════╕
# │ Region Name   │     P-Value │
# ╞═══════════════╪═════════════╡
# │ L_V6          │ 2.34594e-05 │
# ├───────────────┼─────────────┤
# │ L_V3A         │ 1.25418e-05 │
# ├───────────────┼─────────────┤
# │ L_V7          │ 0.000401624 │
# ├───────────────┼─────────────┤
# │ L_FFC         │ 0.000413493 │
# ├───────────────┼─────────────┤
# │ L_1           │ 7.28713e-05 │
# ├───────────────┼─────────────┤
# │ L_ProS        │ 0.0108309   │
# ├───────────────┼─────────────┤
# │ L_VMV1        │ 0.00102347  │
# ├───────────────┼─────────────┤
# │ R_V6          │ 1.52045e-05 │
# ├───────────────┼─────────────┤
# │ R_55b         │ 0.0275962   │
# ├───────────────┼─────────────┤
# │ R_V3A         │ 3.81144e-08 │
# ├───────────────┼─────────────┤
# │ R_V7          │ 7.28713e-05 │
# ├───────────────┼─────────────┤
# │ R_FFC         │ 0.0487397   │
# ...

# %%
# movie4 vs rest1
t_mr, p_mr_r = st.ttest_rel(m4, r1, alternative='greater')
tf_mr, p_mr = sm.stats.multitest.fdrcorrection(p_mr_r)
count = 0
for n in tf_mr:
    if n:
        count += 1
print("There are " + str(count) + " regions that are significantly different between movie4 and rest1.")
# calculate z values
z_mr = st.norm.ppf(1-p_mr)

regions = m4.columns
for n in range(len(regions)):
    if z_mr[n] < 1.65:
        z_mr[n] = 0
nlp.view_surf(hcp.mesh.inflated,hcp.cortex_data(hcp.unparcellate(z_mr, hcp.mmp)), bg_map=hcp.mesh.sulc, cmap=cm['black_red'], threshold=1.65, symmetric_cmap = False, vmax = 6, vmin = 1.65).save_as_html('z_m4r1.html')

tb = [['Region Name', 'P-Value']]
for n in range(len(regions)):
    p = p_mr[n]
    if p <= 0.05:
        tb.append([regions[n],p])

print(len(tb)-1)
print(tabulate(tb, headers='firstrow', tablefmt='fancy_grid'))
# Out:
# There are 11 regions that are significantly different between movie4 and rest1.
# 11
# ╒═══════════════╤═════════════╕
# │ Region Name   │     P-Value │
# ╞═══════════════╪═════════════╡
# │ L_V6          │ 0.000117553 │
# ├───────────────┼─────────────┤
# │ L_V3A         │ 8.17886e-10 │
# ├───────────────┼─────────────┤
# │ L_1           │ 0.000387679 │
# ├───────────────┼─────────────┤
# │ R_V6          │ 0.00037814  │
# ├───────────────┼─────────────┤
# │ R_V3A         │ 3.4815e-08  │
# ├───────────────┼─────────────┤
# │ R_V7          │ 0.000310822 │
# ├───────────────┼─────────────┤
# │ R_PSL         │ 0.0148794   │
# ├───────────────┼─────────────┤
# │ R_7PC         │ 0.0256486   │
# ├───────────────┼─────────────┤
# │ R_1           │ 0.0135702   │
# ├───────────────┼─────────────┤
# │ R_PH          │ 0.000229277 │
# ├───────────────┼─────────────┤
# │ R_VMV1        │ 9.16615e-05 │
# ╘═══════════════╧═════════════╛

# %%
# movie1 vs rest all
t_mr, p_mr_r = st.ttest_ind(m1, r_all, alternative='greater')
tf_mr, p_mr = sm.stats.multitest.fdrcorrection(p_mr_r)
count = 0
for n in tf_mr:
    if n:
        count += 1
print("There are " + str(count) + " regions that are significantly different between movie1 and rest.")
# calculate z values
z_mr = st.norm.ppf(1-p_mr)

regions = m1.columns
for n in range(len(regions)):
    if z_mr[n] < 1.65:
        z_mr[n] = 0
nlp.view_surf(hcp.mesh.inflated,hcp.cortex_data(hcp.unparcellate(z_mr, hcp.mmp)), bg_map=hcp.mesh.sulc, cmap=cm['black_red'], 
              threshold=1.65, symmetric_cmap = False, vmax = 6, vmin = 1.65).save_as_html('z_m1r.html')

tb = [['Region Name', 'P-Value']]
for n in range(len(regions)):
    p = p_mr[n]
    if p <= 0.05:
        tb.append([regions[n],p])

print(len(tb)-1)
print(tabulate(tb, headers='firstrow', tablefmt='fancy_grid'))
# Out:
# There are 18 regions that are significantly different between movie1 and rest.
# 18
# ╒═══════════════╤═════════════╕
# │ Region Name   │     P-Value │
# ╞═══════════════╪═════════════╡
# │ L_V6          │ 9.02898e-10 │
# ├───────────────┼─────────────┤
# │ L_V3A         │ 2.21662e-15 │
# ├───────────────┼─────────────┤
# │ L_V7          │ 0.000692368 │
# ├───────────────┼─────────────┤
# │ L_FFC         │ 0.00910132  │
# ├───────────────┼─────────────┤
# │ L_1           │ 0.00137078  │
# ├───────────────┼─────────────┤
# │ L_A5          │ 0.000471665 │
# ├───────────────┼─────────────┤
# │ L_VMV1        │ 0.000578765 │
# ├───────────────┼─────────────┤
# │ R_V6          │ 1.18505e-06 │
# ├───────────────┼─────────────┤
# │ R_V3A         │ 4.41302e-14 │
# ├───────────────┼─────────────┤
# │ R_V7          │ 0.000578765 │
# ├───────────────┼─────────────┤
# │ R_PSL         │ 0.00192305  │
# ├───────────────┼─────────────┤
# │ R_STV         │ 0.0188019   │
# ...

# %%
# movie2 vs rest all
t_mr, p_mr_r = st.ttest_ind(m2, r_all, alternative='greater')
tf_mr, p_mr = sm.stats.multitest.fdrcorrection(p_mr_r)
count = 0
for n in tf_mr:
    if n:
        count += 1
print("There are " + str(count) + " regions that are significantly different between movie2 and rest.")
# calculate z values
z_mr = st.norm.ppf(1-p_mr)

regions = m2.columns
for n in range(len(regions)):
    if z_mr[n] < 1.65:
        z_mr[n] = 0
nlp.view_surf(hcp.mesh.inflated,hcp.cortex_data(hcp.unparcellate(z_mr, hcp.mmp)), bg_map=hcp.mesh.sulc, cmap=cm['black_red'], 
              threshold=1.65, symmetric_cmap = False, vmax = 6, vmin = 1.65).save_as_html('z_m2r.html')

tb = [['Region Name', 'P-Value']]
for n in range(len(regions)):
    p = p_mr[n]
    if p <= 0.05:
        tb.append([regions[n],p])

print(len(tb)-1)
print(tabulate(tb, headers='firstrow', tablefmt='fancy_grid'))
# Out:
# There are 39 regions that are significantly different between movie2 and rest.
# 39
# ╒═══════════════╤═════════════╕
# │ Region Name   │     P-Value │
# ╞═══════════════╪═════════════╡
# │ L_V6          │ 8.0475e-12  │
# ├───────────────┼─────────────┤
# │ L_V2          │ 0.0329084   │
# ├───────────────┼─────────────┤
# │ L_V3A         │ 1.00528e-20 │
# ├───────────────┼─────────────┤
# │ L_V7          │ 3.17829e-06 │
# ├───────────────┼─────────────┤
# │ L_A1          │ 0.0252582   │
# ├───────────────┼─────────────┤
# │ L_1           │ 0.0167232   │
# ├───────────────┼─────────────┤
# │ L_p24pr       │ 0.0498372   │
# ├───────────────┼─────────────┤
# │ L_OP4         │ 0.0167232   │
# ├───────────────┼─────────────┤
# │ L_52          │ 0.00370452  │
# ├───────────────┼─────────────┤
# │ L_FOP3        │ 0.00365772  │
# ├───────────────┼─────────────┤
# │ L_PHT         │ 0.0440198   │
# ├───────────────┼─────────────┤
# │ L_DVT         │ 0.0438069   │
# ...

# %%
# movie3 vs rest all
t_mr, p_mr_r = st.ttest_ind(m3, r_all, alternative='greater')
tf_mr, p_mr = sm.stats.multitest.fdrcorrection(p_mr_r)
count = 0
for n in tf_mr:
    if n:
        count += 1
print("There are " + str(count) + " regions that are significantly different between movie3 and rest.")
# calculate z values
z_mr = st.norm.ppf(1-p_mr)

regions = m3.columns
for n in range(len(regions)):
    if z_mr[n] < 1.65:
        z_mr[n] = 0
nlp.view_surf(hcp.mesh.inflated,hcp.cortex_data(hcp.unparcellate(z_mr, hcp.mmp)), bg_map=hcp.mesh.sulc, cmap=cm['black_red'], 
              threshold=1.65, symmetric_cmap = False, vmax = 6, vmin = 1.65).save_as_html('z_m3r.html')

tb = [['Region Name', 'P-Value']]
for n in range(len(regions)):
    p = p_mr[n]
    if p <= 0.05:
        tb.append([regions[n],p])

print(len(tb)-1)
print(tabulate(tb, headers='firstrow', tablefmt='fancy_grid'))
# Out:
# There are 21 regions that are significantly different between movie3 and rest.
# 21
# ╒═══════════════╤═════════════╕
# │ Region Name   │     P-Value │
# ╞═══════════════╪═════════════╡
# │ L_V6          │ 2.76625e-13 │
# ├───────────────┼─────────────┤
# │ L_V3A         │ 8.39027e-12 │
# ├───────────────┼─────────────┤
# │ L_V7          │ 3.45983e-08 │
# ├───────────────┼─────────────┤
# │ L_FFC         │ 0.00152237  │
# ├───────────────┼─────────────┤
# │ L_1           │ 0.00254555  │
# ├───────────────┼─────────────┤
# │ L_ProS        │ 0.00254555  │
# ├───────────────┼─────────────┤
# │ L_A5          │ 0.00413078  │
# ├───────────────┼─────────────┤
# │ L_V6A         │ 0.0142447   │
# ├───────────────┼─────────────┤
# │ L_VMV1        │ 2.29411e-08 │
# ├───────────────┼─────────────┤
# │ L_Ig          │ 0.0172779   │
# ├───────────────┼─────────────┤
# │ R_V6          │ 7.21251e-09 │
# ├───────────────┼─────────────┤
# │ R_V3A         │ 1.16204e-17 │
# ...

# %%
# movie4 vs rest all
t_mr, p_mr_r = st.ttest_ind(m4, r_all, alternative='greater')
tf_mr, p_mr = sm.stats.multitest.fdrcorrection(p_mr_r)
count = 0
for n in tf_mr:
    if n:
        count += 1
print("There are " + str(count) + " regions that are significantly different between movie4 and rest.")
# calculate z values
z_mr = st.norm.ppf(1-p_mr)

regions = m4.columns
for n in range(len(regions)):
    if z_mr[n] < 1.65:
        z_mr[n] = 0
nlp.view_surf(hcp.mesh.inflated,hcp.cortex_data(hcp.unparcellate(z_mr, hcp.mmp)), bg_map=hcp.mesh.sulc, cmap=cm['black_red'], 
              threshold=1.65, symmetric_cmap = False, vmax = 6, vmin = 1.65).save_as_html('z_m4r.html')

tb = [['Region Name', 'P-Value']]
for n in range(len(regions)):
    p = p_mr[n]
    if p <= 0.05:
        tb.append([regions[n],p])

print(len(tb)-1)
print(tabulate(tb, headers='firstrow', tablefmt='fancy_grid'))
# Out:
# There are 17 regions that are significantly different between movie4 and rest.
# 17
# ╒═══════════════╤═════════════╕
# │ Region Name   │     P-Value │
# ╞═══════════════╪═════════════╡
# │ L_V6          │ 2.54161e-10 │
# ├───────────────┼─────────────┤
# │ L_V2          │ 0.0360119   │
# ├───────────────┼─────────────┤
# │ L_V3A         │ 9.62288e-27 │
# ├───────────────┼─────────────┤
# │ L_V7          │ 0.0002378   │
# ├───────────────┼─────────────┤
# │ L_1           │ 0.00779958  │
# ├───────────────┼─────────────┤
# │ L_VMV1        │ 0.000558318 │
# ├───────────────┼─────────────┤
# │ R_V6          │ 5.44317e-06 │
# ├───────────────┼─────────────┤
# │ R_V3A         │ 1.77036e-17 │
# ├───────────────┼─────────────┤
# │ R_V7          │ 3.48385e-06 │
# ├───────────────┼─────────────┤
# │ R_PSL         │ 4.89473e-05 │
# ├───────────────┼─────────────┤
# │ R_5mv         │ 0.0445483   │
# ├───────────────┼─────────────┤
# │ R_7PC         │ 0.0366209   │
# ...

# %%
# movie all vs rest all
t_mr, p_mr_r = st.ttest_rel(m_all, r_all, alternative='greater')
tf_mr, p_mr = sm.stats.multitest.fdrcorrection(p_mr_r)
count = 0
for n in tf_mr:
    if n:
        count += 1
print("There are " + str(count) + " regions that are significantly different between movie and rest.")
# calculate z values
z_mr = st.norm.ppf(1-p_mr)
# Out:
# There are 67 regions that are significantly different between movie and rest.

# %%
regions = m_all.columns
for n in range(len(regions)):
    if z_mr[n] < 1.65:
        z_mr[n] = 0
nlp.view_surf(hcp.mesh.inflated,hcp.cortex_data(hcp.unparcellate(z_mr, hcp.mmp)), bg_map=hcp.mesh.sulc, cmap=cm['black_red'], threshold=1.65, symmetric_cmap = False, vmax = 6, vmin = 1.65).save_as_html('z_mr.html')

tb = [['Region Name', 'P-Value']]
for n in range(len(regions)):
    p = p_mr[n]
    if p <= 0.05:
        tb.append([regions[n],p])

print(len(tb)-1)
print(tabulate(tb, headers='firstrow', tablefmt='fancy_grid'))
# Out:
# 67
# ╒════════════════════╤═════════════╕
# │ Region Name        │     P-Value │
# ╞════════════════════╪═════════════╡
# │ L_V1               │ 0.0272135   │
# ├────────────────────┼─────────────┤
# │ L_V6               │ 4.59377e-24 │
# ├────────────────────┼─────────────┤
# │ L_V2               │ 0.000953211 │
# ├────────────────────┼─────────────┤
# │ L_3b               │ 0.0484494   │
# ├────────────────────┼─────────────┤
# │ L_V3A              │ 8.44261e-33 │
# ├────────────────────┼─────────────┤
# │ L_V7               │ 2.50217e-16 │
# ├────────────────────┼─────────────┤
# │ L_FFC              │ 1.59299e-07 │
# ├────────────────────┼─────────────┤
# │ L_V3B              │ 0.000193935 │
# ├────────────────────┼─────────────┤
# │ L_PIT              │ 0.0261241   │
# ├────────────────────┼─────────────┤
# │ L_7m               │ 0.000502748 │
# ├────────────────────┼─────────────┤
# │ L_v23ab            │ 1.01197e-07 │
# ├────────────────────┼─────────────┤
# ...

# %%
# task1 vs rest1
t_rr, p_rr_r = st.ttest_rel(t1, r1, alternative='greater')
tf_rr, p_rr = sm.stats.multitest.fdrcorrection(p_rr_r)
count = 0
for n in tf_rr:
    if n:
        count += 1
print("There are " + str(count) + " regions that are significantly different between retbar1 and rest1.")
# calculate z values
z_rr = st.norm.ppf(1-p_rr)
# Out:
# There are 57 regions that are significantly different between retbar1 and rest1.

# %%
regions = t1.columns
for n in range(len(regions)):
    if z_rr[n] < 1.65:
        z_rr[n] = 0
nlp.view_surf(hcp.mesh.inflated,hcp.cortex_data(hcp.unparcellate(z_rr, hcp.mmp)), bg_map=hcp.mesh.sulc, cmap=cm['black_red'], threshold=1.65, symmetric_cmap = False, vmax = 6, vmin = 1.65).save_as_html('z_t1r1.html')

tb = [['Region Name', 'P-Value']]
for n in range(len(regions)):
    p = p_rr[n]
    if p <= 0.05:
        tb.append([regions[n],p])

print(len(tb)-1)
print(tabulate(tb, headers='firstrow', tablefmt='fancy_grid'))
# Out:
# 57
# ╒═══════════════╤═════════════╕
# │ Region Name   │     P-Value │
# ╞═══════════════╪═════════════╡
# │ L_MST         │ 0.0101009   │
# ├───────────────┼─────────────┤
# │ L_V6          │ 0.0156754   │
# ├───────────────┼─────────────┤
# │ L_V2          │ 8.19251e-06 │
# ├───────────────┼─────────────┤
# │ L_V3          │ 5.27462e-08 │
# ├───────────────┼─────────────┤
# │ L_V4          │ 3.06593e-15 │
# ├───────────────┼─────────────┤
# │ L_V8          │ 2.87579e-12 │
# ├───────────────┼─────────────┤
# │ L_3b          │ 0.0471174   │
# ├───────────────┼─────────────┤
# │ L_V3A         │ 3.06593e-15 │
# ├───────────────┼─────────────┤
# │ L_V7          │ 2.39916e-09 │
# ├───────────────┼─────────────┤
# │ L_V3B         │ 8.37438e-10 │
# ├───────────────┼─────────────┤
# │ L_LO1         │ 0.00011904  │
# ├───────────────┼─────────────┤
# │ L_MT          │ 1.33891e-09 │
# ├───────────────┼─────────────┤
# │ L_PCV         │ 0.0288871   │
# ├───────────────┼─────────────┤
# ...

# %%
# task vs rest
t_rr, p_rr_r = st.ttest_ind(t_all, r_all, alternative='greater')
tf_rr, p_rr = sm.stats.multitest.fdrcorrection(p_rr_r)
count = 0
for n in tf_rr:
    if n:
        count += 1
print("There are " + str(count) + " regions that are significantly different between task_all and rest_all.")
# calculate z values
z_rr = st.norm.ppf(1-p_rr)
# Out:
# There are 182 regions that are significantly different between task_all and rest_all.

# %%
regions = t_all.columns
for n in range(len(regions)):
    if z_rr[n] < 1.65:
        z_rr[n] = 0
nlp.view_surf(hcp.mesh.inflated,hcp.cortex_data(hcp.unparcellate(z_rr, hcp.mmp)), bg_map=hcp.mesh.sulc, cmap=cm['black_red'], threshold=1.65, symmetric_cmap = False, vmax = 6, vmin = 1.65).save_as_html('z_tr.html')

tb = [['Region Name', 'P-Value']]
for n in range(len(regions)):
    p = p_rr[n]
    if p <= 0.05:
        tb.append([regions[n],p])

print(len(tb)-1)
print(tabulate(tb, headers='firstrow', tablefmt='fancy_grid'))
# Out:
# 182
# ╒════════════════════╤═════════════╕
# │ Region Name        │     P-Value │
# ╞════════════════════╪═════════════╡
# │ L_MST              │ 1.43108e-09 │
# ├────────────────────┼─────────────┤
# │ L_V6               │ 1.91341e-26 │
# ├────────────────────┼─────────────┤
# │ L_V2               │ 3.7496e-20  │
# ├────────────────────┼─────────────┤
# │ L_V3               │ 9.78946e-23 │
# ├────────────────────┼─────────────┤
# │ L_V4               │ 2.89238e-30 │
# ├────────────────────┼─────────────┤
# │ L_V8               │ 1.23879e-29 │
# ├────────────────────┼─────────────┤
# │ L_3b               │ 1.16475e-07 │
# ├────────────────────┼─────────────┤
# │ L_V3A              │ 1.10228e-67 │
# ├────────────────────┼─────────────┤
# │ L_POS2             │ 0.00102799  │
# ├────────────────────┼─────────────┤
# │ L_V7               │ 7.15528e-36 │
# ├────────────────────┼─────────────┤
# │ L_FFC              │ 3.58594e-05 │
# ├────────────────────┼─────────────┤
# ...
